# %%
# Add Pandas dependency
import pandas as pd

# Load files
donors2008_to_load = "donors2008.csv"

donors2008_df = pd.read_csv(donors2008_to_load)
donors2008_df
# Out:
#         LastName FirstName          Employer           City State    Zip  \
# 0          Aaron    Eugene  State Department         Dulles    VA  20189
# 1          Abadi   Barbara       Abadi & Co.       New York    NY  10021
# 2        Adamany   Anthony           Retired       Rockford    IL  61103
# 3          Adams  Lorraine              Self       New York    NY  10026
# 4          Adams    Marion              None         Exeter    NH  03833
# ...          ...       ...               ...            ...   ...    ...
# 1771   Zinczenko     David            Rodale      Allentown    PA  18102
# 1772  Zschiesche     Peter               NaN      San Diego    CA  92104
# 1773  Zweidinger      Ruth               NaN   Hillsborough    NC  27278
# 1774   Zwerdling     David    Montg Cnty, Md  Silver Spring    MD  20910
# 1775     Zyskind       Jon      JDS Uniphase        Concord    MA  10742
#
#       Amount  FIELD8
# 0      500.0     NaN
# 1      200.0     NaN
# 2      500.0     NaN
# ...

# %%
per_state_amount_average = donors2008_df.groupby(["State"]).mean()["Amount"]

# %%
print(per_state_amount_average)
# Out:
# State
# AE     100.000000
# AK     175.000000
# AL     212.500000
# AP     200.000000
# AR     350.000000
# AZ     206.000000
# CA     685.234973
# CO     851.250000
# CT     825.714286
# DC     647.115385
# DE     190.000000
# FL     709.358974
# GA     842.307692
# HI     195.454545
# IA     600.000000
# ID     341.666667
# IL    1114.519231
# IN     225.000000
# KS     283.333333
# KY     735.000000
# LA     158.333333
# MA     750.714286
# MD     819.823529
# ME     211.111111
# MI     241.666667
# MN     697.000000
# MO     463.888889
# MS    1208.333333
# MT     200.000000
# NC     440.625000
# NE     183.333333
# NH     368.750000
# NJ     276.111111
# NM     298.913043
# NV     393.333333
# NY     910.829146
# OH     501.562500
# OK     200.000000
# OR     321.052632
# PA     896.755556
# QC     250.000000
# RI     700.000000
# SC     287.500000
# TN     257.142857
# TX     485.193182
# UT     200.000000
# VA     701.093465
# VI     225.000000
# VT     350.000000
# ...
